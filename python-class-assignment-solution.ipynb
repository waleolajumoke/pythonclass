# %%
# 1. create a program that finds the largest of 3 numbers entered by the user

# num1 = int(input("Enter first number"))
# num2 = int(input("Enter second number"))
# num3 = int(input("Enter third number"))
# if num1 > num2 and num1 > num3:
#     print(num1, "is the largest")
#     print(f"{num1} is the largest")
# elif num2 > num1 and num2 > num3:
#     print(f"{num2} is the largest")
# elif num3 > num1 and num3 > num2:
#     print(f"{num3} is the largest")
# else:
#     print("no largest found")

# 2. Create a function that extracts the last four digits from the input entered by the user
# number = input("Enter some digits")
def last_four(x):
    return str(x)[-4:]
last_four(number)

# 3. Create a program that accepts 2 numbers and an operator eg. 5 6, + then perform an operation based on what the user enters eg 5 + 6 if the user enters 2, 8, * it should return 2 * 8 and show the answer
# num1 = int(input("Enter first number"))
# num2 = int(input("Enter second number"))
# sign = input("Enter the operator")
# if sign == "+":
#     print(num1 + num2)
# elif sign == "-":
#     print(num1 - num2)
# elif sign == "*":
#     print(num1 * num2)
# elif sign == "/":
#     print(num1 / num2)
# else:
#     print("Invalid operation")

# 4. create a program that takes a score and shows the grade based on the score
# eg.
# 90 - 100 ("Grade A")
# 70 - 89  ("Grade B")
# 50 - 69 ("Grade c")
# 30 - 49 ("Grade E")
# 0 - 29  ("Grade E")

# score = int(input("Enter student score"))
# if score >= 90 and score <= 100:
#     print("Grade A")
# elif score >= 70 and score <= 89:
#     print("Grade B")
# elif score >= 50 and score <= 69:
#     print("Grade C")
# elif score >= 30 and score <= 49:
#     print("Grade D")
# elif score >= 0 and score <= 29:
#     print("Grade E")
# else:
#     print("Invalid score")
    
# 5. create a guessing game. generate a number that is stored in a variable and let the user guess the number.
# If they guess correctly, tell them they are correct. if higher than the number tell them it is higher. if lower tell them their guess is lower.

# import random
# number = random.randint(1,10)
# guess = int(input("Guess a number between 1 and 10\n"))
# if guess > number and guess <= 10:
#     print("Your guess is higher", "random number is", number)
# elif guess < number and guess <= 10:
#     print("Your guess is lower", number)
# elif guess == number:
#     print("You win")
# else:
#     print("Invalid entry")

# import random
# x = random.randint(1,10)
# def guessing_game(number):
#     guess = int(input("Guess a number between 1 and 10\n"))
#     if guess > number and guess <= 10:
#         print("Your guess is higher", "random number is", number)
#     elif guess < number and guess <= 10:
#         print("Your guess is lower", number)
#     elif guess == number:
#         print("You win")
#     else:
#         print("Invalid entry")
        
# guessing_game(x)
